# %% [markdown]
# Link colab tugas menghitung jarak
#
# https://colab.research.google.com/drive/13p6_DXozb2151e71XaAfgiw230wJD3QW#scrollTo=4fDVe498l54I

# %% [markdown]
# # Tugas 1 Menghitung Jarak

# %%
import numpy as np
import pandas as pd
import seaborn as sb
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
data = pd.read_csv("https://raw.githubusercontent.com/achmadbaharuddinakbar/datamining/achmadbaharuddinakbar-data-file/StudentsPerformance.csv")
print(data)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
def dt1(i,j):
  P = 9
  Q = 0
  for col in ["gender", "lunch", "test preparation course", "math score", "reading score", "writing score"]:
    if data[col][i] == data[col][j]:
      Q += 1
  return (P-Q)/P

# %%
print(dt1(1,2))
print(dt1(1,3))
print(dt1(1,4))
# Out:
# 0.7777777777777778
# 1.0
# 0.8888888888888888

# %%
def dt2(i,j,h):
  result = 0
  for col in ["math score", "reading score","writing score"]:
    result = math.pow(abs(data[col][i] - data[col][j]), h)
  return result**(1/h)

# %%
print(dt2(1,2,1))
print(dt2(1,3,1))
print(dt2(1,4,1))
# Out:
# 5.0
# 44.0
# 13.0
