# %% [markdown]
# Link colab tugas-3 KNN
#
# https://colab.research.google.com/drive/1xT4tH7T_fOVYKQJeCzCEBjNm8yrFGcOv#scrollTo=0BBNpPOR226N

# %% [markdown]
# # Tugas 3 : K-Nearest Neighbors

# %% [markdown]
# ## Baca Data
#
#
# *   Baca data dengan *library pandas* *italicized text*
# *   Data [Bunga Iris](https://raw.githubusercontent.com/achmadbaharuddinakbar/datamining/gh-pages/Iris.csv)

# %% [markdown]
# #### Persiapan Lingkungan
#
#
# *   Impor *train_test_split* dari *sklearn*
# *   Impor *KNeighborsClassifier* dari *sklearn*
# *   Impor *pandas library*

# %%
#split dataset into train and test data
from sklearn.model_selection import train_test_split

# %%
# Create KNN classifier
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd

# %%
dataset_url = 'https://raw.githubusercontent.com/achmadbaharuddinakbar/datamining/achmadbaharuddinakbar-data-file/Iris.csv'

# %%
df = pd.read_csv(dataset_url)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#check number of rows and columns in dataset
df.shape
# Out:
# (150, 6)

# %% [markdown]
# ### Hitung Data
#
# *   Pisahkan kolom "Species" dari *dataframe*
# *   Ambil kolom "Species" sebagai target kolom untuk kategori kelas
# *   Pisahkan data latih dengan data tes
#
#
# ```
# # data latih (nilai data)
# X_train
#
# # data tes (nilai data)
# X_test
#
# # data latih (kelas data)
# y_train
#
# # data tes (kelas data)
# y_test
# ```

# %%
#create a dataframe with all training data except the target column

X = df.drop(columns=['Species'])
#check that the target variable has been removed
X.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2

# %%
# separate target values
y = df['Species'].values  # view target values
y[0:5]
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
# percent_amount_of_test_data = / HUNDRED_PERCENT
percent_amount_of_test_data = 0.2

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = percent_amount_of_test_data, random_state=1, stratify=y)

# %% [markdown]
# *   Tentukan nilai K = 10 (10 tetangga terdekat)
# *   Buat data latih
#
#
# ```
# knn_classifier.fit(train_data)
# ```

# %%
amount_of_neighbor = 3

# %%
# Fit the classifier to the data
knn = KNeighborsClassifier(n_neighbors = amount_of_neighbor)

# create train data
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# *   Tes data target terhadap data latih
# *   Tampilkan predksi 10 data pertama
#
#
#
# ```
# knn_classifier.predict(test_data)
# ```

# %%
#show first 5 model predictions on the test data
knn.predict(X_test)[0:30]
# Out:
# array(['Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor'], dtype=object)

# %% [markdown]
# *   Cetak prediksi nilai dari data tes
#
#
#
# ```
# knn_classifier.score(test_data)
# ```

# %%
#check accuracy of our model on the test data
knn.score(X_test, y_test)
# Out:
# 1.0
